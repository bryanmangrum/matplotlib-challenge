# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_df = mouse_metadata.merge(study_results, how='outer', on='Mouse ID')
combined_df.head()

# Display the data table for preview
combined_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
mouse_count = combined_df['Mouse ID'].nunique()
mouse_count
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dup_id = combined_df[combined_df.duplicated(subset = ['Mouse ID', 'Timepoint'])]
dup_id
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
dup_mouse = combined_df.set_index('Mouse ID')

dup_mouse = dup_mouse.loc['g989']

dup_mouse
# Out:
#          Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         20
# g989         Propriva  Female          21          26         20
# g989         Propriva  Female          21          26         25
# g989         Propriva  Female          21          26         30
# g989         Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
combined_df = combined_df.drop(combined_df[combined_df['Mouse ID']=='g989'].index)

# %%
# Checking the number of mice in the clean DataFrame.
new_mouse_count = combined_df['Mouse ID'].nunique()
new_mouse_count
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
tumor_vol_summary = combined_df.groupby('Drug Regimen')
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

tumor_mean = tumor_vol_summary["Tumor Volume (mm3)"].mean()
tumor_med = tumor_vol_summary["Tumor Volume (mm3)"].median()
tumor_var = tumor_vol_summary["Tumor Volume (mm3)"].var()
tumor_stdev = tumor_vol_summary["Tumor Volume (mm3)"].std()
tumor_SEM = tumor_vol_summary["Tumor Volume (mm3)"].sem()

summary = pd.DataFrame({'Mean':tumor_mean, 'Median':tumor_med, 'Variance':tumor_var, 'Standard Dev':tumor_stdev, 'SEM':tumor_SEM})
summary
# Out:
#                    Mean     Median   Variance  Standard Dev       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764      4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177      6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684      6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577      8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479      8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083      7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013      6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704      4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562      7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355      6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
tumor_vol_summary2 = combined_df.groupby('Drug Regimen')
# Using the aggregation method, produce the same summary statistics in a single line
summary2 = tumor_vol_summary2.aggregate({'Tumor Volume (mm3)':['mean', 'median', 'var', 'std', 'sem']})
summary2
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
timepoints = combined_df.groupby('Drug Regimen')['Timepoint'].count()
tp_sort = timepoints.sort_values(ascending=False).plot.bar()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
timepoints=timepoints.sort_values(ascending=False)
plt.bar(timepoints.index, timepoints.values, color='purple')

plt.title("Mice Tested by Regimen")
plt.xticks(rotation=45)
plt.xlabel("Drug Regimen")
plt.ylabel("Timepoints")

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
sex_dist = combined_df.groupby('Sex')['Mouse ID'].count()
sex_pie = sex_dist.plot.pie(autopct = "%1.0f%%")

sex_pie.set_title('Mouse Distribution by Sex')
# Out:
# Text(0.5, 1.0, 'Mouse Distribution by Sex')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(sex_dist, labels = ['Female', 'Male'],  autopct = "%1.1f%%", colors=('red','blue'))
plt.title('Mouse Distribution by Sex')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
treat = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Start by getting the last (greatest) timepoint for each mouse
max_tp = combined_df.groupby('Mouse ID')['Timepoint'].max()
max_tp_df = pd.DataFrame(max_tp)

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
new_combined_df = pd.merge(combined_df, max_tp_df, how='inner', on=('Mouse ID', 'Timepoint'))
new_combined_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane    Male          21          16         45
# 1       s185    Capomulin  Female           3          17         45
# 2       x401    Capomulin  Female          16          15         45
# 3       m601    Capomulin    Male          22          17         45
# 4       g791     Ramicane    Male          11          16         45
# ..       ...          ...     ...         ...         ...        ...
# 243     z314     Stelasyn  Female          21          28          5
# 244     z435     Propriva  Female          12          26         10
# 245     z581    Infubinol  Female          24          25         45
# 246     z795     Naftisol  Female          13          29         45
# 247     z969     Naftisol    Male           9          30         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             22.050126                 1
# 1             23.343598                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty dictionary to fill with tumor vol data (for plotting)
tumor_vols = {}

# Empty data frame to build summary into
quartiles = pd.DataFrame()

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for regimen in treatments:
    # Locate the rows which contain mice on each drug and get the tumor volumes
    regimen_subset = new_combined_df.loc[new_combined_df['Drug Regimen'] == regimen, 'Tumor Volume (mm3)']
    #  subset to dictionary
    tumor_vols[regimen] = list(regimen_subset)
    
    # Determine outliers using upper and lower bounds
    subset_quartiles = regimen_subset.quantile([0.25, 0.5, 0.75])
    lowerq = subset_quartiles[0.25]
    medianq = subset_quartiles[0.5]
    upperq = subset_quartiles[0.75]
    iqr = upperq - lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    

    quart_list = [
        {
            'drug': regimen, 
            'lower quartile': lowerq, 
            'median': medianq, 
            'upper quartile': upperq, 
            'iqr': iqr, 
            'lower bound': lower_bound, 
            'upper bound': upper_bound
        }
    ]
    subset_quart = pd.DataFrame(quart_list)

    # Append to empty summary data frame
    quartiles = quartiles.append(subset_quart)

    # Print drug regimen's potential upper and lower outliers
    print(f'{regimen} potential outliers:')
    print(f'Tumor volumes below {lower_bound:.2f} could be outliers.')
    print(f'Tumor volumes above {upper_bound:.2f} could be outliers.\n')

# Set index of summary data frame to drug regimens of interest
quartiles = quartiles.set_index(['drug'])

# Display all four regimens of interest
quartiles.head(4)
# Out:
# Capomulin potential outliers:
# Tumor volumes below 20.70 could be outliers.
# Tumor volumes above 51.83 could be outliers.
#
# Ramicane potential outliers:
# Tumor volumes below 17.91 could be outliers.
# Tumor volumes above 54.31 could be outliers.
#
# Infubinol potential outliers:
# Tumor volumes below 36.83 could be outliers.
# Tumor volumes above 82.74 could be outliers.
#
# Ceftamin potential outliers:
# Tumor volumes below 25.36 could be outliers.
# Tumor volumes above 87.67 could be outliers.
#            lower quartile     median  upper quartile        iqr  lower bound  \
# drug
# Capomulin       32.377357  38.125164       40.159220   7.781863    20.704562
# Ramicane        31.560470  36.561652       40.659006   9.098537    17.912664
# Infubinol       54.048608  60.165180       65.525743  11.477135    36.832905
# Ceftamin        48.722078  59.851956       64.299830  15.577752    25.355450
#
#            upper bound
# drug
# Capomulin    51.832015
# Ramicane     54.306811
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
marker = {'markerfacecolor': 'purple', 'marker': 'D'}

# Set up box plots using tumor_vol dictionary holding each drug's tumor volume values
fig1, ax1 = plt.subplots()
ax1.boxplot(tumor_vols.values(), flierprops=marker)

# Format ticks to be each drug, set labels and title
ax1.set_xticklabels(tumor_vols.keys())
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.set_xlabel('Drug Regimen')
ax1.set_title('Final Tumor Volumes for All Mice Treated By Drug Regimen')

# Display plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
mouse_df = combined_df.loc[combined_df['Mouse ID'] == 'i557', ['Timepoint', 'Tumor Volume (mm3)']]
mouse_df = mouse_df.set_index(['Timepoint'])

# Plot timepoints and tumor volume
mouse_df.plot(
    title="Mouse i557's Tumor Volume As Treated By Capomulin Over 45 Days",
    xlabel="Number of Days", 
    ylabel="Tumor Volume (mm3)", 
    legend=False,
    grid=True
)

# Display line plot
plt.xlim(mouse_df.index.min(), mouse_df.index.max())
plt.minorticks_on()
plt.tight_layout()
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capomulin_df = combined_df.loc[combined_df['Drug Regimen'] == 'Capomulin']

# Group by weight AND Mouse ID
weights = capomulin_df.groupby(['Weight (g)', 'Mouse ID'])

# Determine mean tumor volumes 
avg_vol = weights['Tumor Volume (mm3)'].mean()

# Plot with matplotlib
plt.scatter(
    avg_vol.index.get_level_values('Weight (g)'), 
    avg_vol, 
    marker='o', 
    facecolors='purple', 
    edgecolors='black', 
    s=50, 
    alpha=0.75
)

# Add labels and title
plt.title('Average Tumor Volume by Individual Mouse Weight as Treated By Capomulin')
plt.xlabel('Mouse Weight (g)')
plt.ylabel('Mean Tumor Volume (mm3)')

# Display plot
plt.minorticks_on()
plt.grid()
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 

(slope, yint, rval, pval, sterr) = st.linregress(avg_vol.index.get_level_values('Weight (g)'), avg_vol)

print(f"The r-value (correlation coefficient) between individual mouse weights and their average tumor volume as treated by Capomulin is {round(rval, 2)}.")

# Get "y" values for our regression line. Use x values from data, multiply by slope, add by y-intercept
regress_val = avg_vol.index.get_level_values('Weight (g)') * slope + yint

# Equation of regression line for later annotation
line_eq = f"y = {round(slope, 2)}x + {round(yint, 2)}"

# Redraw scatter plot
plt.scatter(
    avg_vol.index.get_level_values('Weight (g)'), 
    avg_vol, 
    marker='o', 
    facecolors='purple', 
    edgecolors='black', 
    s=50, 
    alpha=0.75
)

# Add labels and title to figure
plt.title('Average Tumor Volume by Individual Mouse Weight as Treated By Capomulin')
plt.xlabel('Mouse Weight (g)')
plt.ylabel('Mean Tumor Volume (mm3)')

# Add ticks and grid
plt.minorticks_on()
plt.grid()

# Plot regression line onto figure
plt.plot(avg_vol.index.get_level_values('Weight (g)'), regress_val, color='b')

# Annotate regression line equation onto figure
plt.annotate(line_eq, (18, 37), fontsize=14, color="b")

# Display figure
plt.show()
# Out:
# The r-value (correlation coefficient) between individual mouse weights and their average tumor volume as treated by Capomulin is 0.84.
